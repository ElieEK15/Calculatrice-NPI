// %%
function pile_vide() {
    return [];
}

function est_vide_pile(p) {
    //return p.length === 0;
    if(p.length==0){return true;}
    else{return false;}
}

function empiler(p, elt) {
    p.push(elt);
}

function depiler(p) {
    return p.pop();
}

// %%
// function appliquer_operation(op, a, b) {
//     switch (op) {
//     case '+':
//         return a + b;
//     case '-':
//         return a - b;
//     case '*':
//         return a * b;
//     case '/':
//         return a / b;
//     default:
//         return 'error';
//  }
// }
function appliquer_operation(op, a, b) {
    if (op =='+'){
        return a + b;
    }
    else if (op =='-'){
        return a - b;
    }
    else if (op =='*'){
        return a*b;
    }
    else if (op =='/'){
        return a/b;
    }
    else{
        return 'error';
    }
}

// %%
function operation(c) {
 return c.split(" ");
}

// %%
function Calculer(s) {
    p=pile_vide();
    for (const i of s) {
        console.log(i);
        if (i === "+" || i === "-" || i === "*" || i === "/") {
        const x = depiler(p);
        const y = depiler(p);
        const r = appliquer_operation(i, parseFloat(y), parseFloat(x));
        empiler(p, r);} 
        else {empiler(p, parseFloat(i));}}
console.log(p);
return p;
}

// %%
const x = prompt('Enter your operation: ');
const z = operation(x);
const y = erj(z);
// Out:
// NetworkError: Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'https://api.basthon.fr/ephemeral'.
// Enter your operation: 10 2 +
